# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv("Titanic_v2.csv")

# %%
ax=sns.countplot(data=df,x="Sex",hue="Survivant")
plt.title("Répartition des survivants selon le genre")
plt.ylabel("Nb Survivant")
# Out:
# Text(0, 0.5, 'Nb Survivant')
